# %% [markdown]
# # COGS 118A: Supervised Machine Learning Algorithms
# ## Data Manipulation and Visualization

# %% [markdown]
# This Jupyter notebook contains starter codes for the coding questions of the assignment I was assigned. I use this notebook as a starting point to code the answers to the coding questions of the assignment, which demonstrates basic data maniputlation, and data visualisation (that included plotting boundaries) with the iris dataset, along with randomly generated data.

# %% [markdown]
# ## Basic NumPy Operations

# %%
import numpy as np
a = np.array([2,1,7])
b = np.array([-2,7,-5])
A = np.array([[2,4], [1,3], [7,9]])
B = np.array([[2,-2], [-3,7], [6,-5]])

# %%
#MY CODE

#        4.1 Vector         #

print("4.1 Vector \n 1. ", a*b)
print(" 2. ", np.dot(a,b))


#        4.2 Matrix         #

print("4.2 Matrix \n 1.\n", A*B)
Atranspose = np.transpose(A)
print(" 2. \n", np.dot(Atranspose, B))
Btranspose = np.transpose(B)
print(" 3. \n", np.dot(A, Btranspose))
# Out:
# 4.1 Vector
#  1.  [ -4   7 -35]
#  2.  -32
# 4.2 Matrix
#  1.
#  [[  4  -8]
#  [ -3  21]
#  [ 42 -45]]
#  2.
#  [[ 43 -32]
#  [ 53 -32]]
#  3.
#  [[-4 22 -8]
#  [-4 18 -9]
#  [-4 42 -3]]

# %% [markdown]
# ## Basic Plots Using Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
space = np.linspace(0, 10, num = 50)
sine = np.sin(space)
sine_5 = sine

for i in range(5):
    sine_5 = sine_5 + np.random.normal(scale = 0.1, size = 50)
    
plt.scatter(space, sine, color = 'b', label = 'sine curve')
plt.plot(space, sine_5, color = 'r', label = 'noise_5_iters')
plt.legend(loc = 'upper right')
plt.show()

# %%
#Code given
np.random.seed(0)
space = np.linspace(0, 10, num = 50)
sine = np.sin(space)
sine_5 = sine

for i in range(5):
    sine_5 = sine_5 + np.random.normal(scale = 0.1, size = 50)
    
#MY CODE
sine_20 = sine
sine_100 = sine

for i in range(20):
    sine_20 = sine_20 + np.random.normal(scale = 0.1, size = 50)
    
for i in range(100):
    sine_100 = sine_100 + np.random.normal(scale = 0.1, size = 50)
    

plt.plot(space, sine_5, color = 'r', label = 'noise_5_iters')
plt.plot(space, sine_20, color = 'y', label = 'noise_20_iters')
plt.plot(space, sine_100, color = 'c', label = 'noise_100_iters')
plt.scatter(space, sine, color = 'b', label = 'sine curve')
plt.legend(loc = 'upper right')
plt.title("Final Plot")
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %% [markdown]
# Load Iris dataset into Python:

# %%
iris = datasets.load_iris()
X = iris.data
Y = iris.target

# %%
#My Code
#Note: the colors on the scatter plots indicate the class
#iris.data

#labelDict = {0: 'Class 1', 1: 'Class 2', 2: 'Class 3'}
plt.scatter(X[:,0], X[:,1], c=Y)

#plt.legend(loc = 'upper left')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
fig = plt.figure(figsize = (6, 6))
ax = Axes3D(fig, elev = -150, azim = 130)
ax.scatter(X[:,0], X[:,1], X[:,2], c=Y)

ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.set_zlabel("Feature 3")
plt.show()

# %% [markdown]
# ## Ploting Decision Boundaries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %config InlineBackend.figure_format ='retina'

def plot_plane(w1, w2, w3, b, num = 30):
  '''Helper function for 7.2; modify this example using plt.plot()instead of Axes3D() to handle 7.1 & 7.3''' 

  X_range = np.linspace(0,10,num)

  # sets up space to plot, 3d equivalent of np.linspace() used for 2d plotting
  X1_plane, X2_plane, X3_plane = np.meshgrid(X_range, X_range, X_range)

  # this defines the equation to plot
  X3_plane = (b + w1 * X1_plane + w2 * X2_plane)/(-w3)

  # does plotting
  fig = plt.figure(figsize = (6, 6))
  ax = Axes3D(fig, elev = -150, azim = 130)
  ax.scatter(X1_plane, X2_plane, X3_plane)
  ax.set_xlabel('$x_1$')
  ax.set_ylabel('$x_2$')
  ax.set_zlabel('$x_3$')
  plt.title("Plane: ${}x_1+{}x_2+{}x_3+{}=0$".format(w1,w2,w3,b))
  plt.show()

# %% [markdown]
# To plot lines and curves in 2-D space, use function ```plt.plot()``` in place of ```Axes3d()```.

# %%
#My Code
def plot_line(w1, w2, b, num = 30):

  X1_line = np.linspace(0,10,num)

  # this defines the equation to plot
  X2_line = (b + w1 * X1_line)/(-w2)

  # does plotting
  fig = plt.figure(figsize = (6, 6))
  #ax = Axes3D(fig, elev = -150, azim = 130)
  plt.plot(X1_line, X2_line)
  plt.xlabel('$x_1$')
  plt.ylabel('$x_2$')

  plt.title("Line: ${}x_1+{}x_2+{}=0$".format(w1,w2,b))
  plt.show()


def plot_curve(w1, w2, b, num = 30):

  theta = np.linspace(0, 2*np.pi, 100)
    
  r = np.sqrt(-1*b)

  x1 = r*np.cos(theta)*w1
  x2 = r*np.sin(theta)*w2
  

  fig, ax = plt.subplots(1)

  plt.plot(x1, x2)
  ax.set_aspect(1)

  plt.xlim(-10,10)
  plt.ylim(-10,10)

  plt.grid(linestyle='--')




  plt.xlabel('$x_1$')
  plt.ylabel('$x_2$')

  plt.title("Curve: ${}x_1^2+{}x_2^2+{}=0$".format(w1,w2,b))
  plt.show()

# %%
plot_plane(3,5,2,-8)

# %%
plot_line(1, 1, -8)

# %%
plot_curve(1,1,-10)

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# Get a row or a column of the array X:

# %%
print(X[0]) # Print the first row of array X.
print(X[:, 0]) # Print the first column of array X.
# ':' here means all rows and '0' means column 0.
# Out:
# [5.1 3.5 1.4 0.2]
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]

# %% [markdown]
# Get part of the array:

# %%
print(X[3:5, 1:3]) # Print 4th and 5th rows, 2nd and 3rd columns.
print(X[:3, :2]) # Print first 3 rows, first 2 columns.
# Out:
# [[3.1 1.5]
#  [3.6 1.4]]
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]]

# %% [markdown]
# Beginning of my Code for Q8

# %%
#MY CODE

#1

print('1.\n', X[:5, :2])

#2

print('\n2.\n The mean:', np.mean(X[:, 1]))
print(' The Variance: ', np.var(X[:, 1]))

#3

w = np.array([3,2,1])
linProj = np.dot(X[:,:3], w)
print('\n3.\n Projected Data Points\n', linProj)
#linProj.shape
print(' Mean: ', np.mean(linProj))

#4

print('\n4.\n 3 Randomly Sampled Data Points')
for i in range(3):
    indice = np.random.randint(0,len(X))
    print(' The sample index is: ', indice, 'and the sample data is: ', X[indice,:])
    
#5

onesCol = np.ones((len(X),1))
newX = np.hstack((X,onesCol))
print('\n5.\n First Data Point of New Array: ', newX[0,:])

#6

onesRow = np.ones((len(X[0])))
newX1 = np.vstack((X,onesRow))
print('\n6.\n First Feature of New Array: ', newX1[:,0])
# Out:
# 1.
#  [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]
#
# 2.
#  The mean: 3.0573333333333337
#  The Variance:  0.1887128888888889
#
# 3.
#  Projected Data Points
#  [23.7 22.1 21.8 21.5 23.6 25.7 22.  23.3 20.4 22.4 25.1 22.8 21.8 20.
#  26.6 27.4 25.3 23.7 26.4 24.4 24.7 24.2 22.  23.6 23.1 22.6 23.4 24.1
#  23.8 22.1 22.2 24.5 25.3 26.3 22.4 22.6 24.8 23.3 20.5 23.6 23.3 19.4
#  20.9 23.6 24.8 21.8 24.5 21.6 24.8 23.  32.1 30.1 31.8 25.1 29.7 27.2
#  30.2 22.8 30.2 24.9 22.5 27.9 26.4 28.8 26.2 30.7 27.3 26.9 27.5 25.7
#  28.9 27.9 28.8 28.6 29.3 30.2 30.8 31.1 28.3 25.8 25.1 25.  26.7 28.5
#  26.7 29.3 31.  27.9 26.9 25.5 26.1 28.9 26.6 22.9 26.4 27.3 27.1 28.7
#  23.3 26.8 31.5 27.9 33.2 30.3 31.3 35.4 24.2 34.  30.9 34.9 31.  29.9
#  31.9 27.1 28.1 30.9 31.  37.4 35.2 27.4 32.8 27.3 35.4 29.2 32.4 34.
#  29.  29.2 30.4 33.4 33.9 37.7 30.4 29.6 29.1 35.2 31.3 30.9 28.8 32.3
#  31.9 32.  27.9 32.7 32.4 31.3 28.9 30.7 30.8 28.8]
#  Mean:  27.402666666666665
#
# 4.
#  3 Randomly Sampled Data Points
#  The sample index is:  68 and the sample data is:  [6.2 2.2 4.5 1.5]
#  The sample index is:  31 and the sample data is:  [5.4 3.4 1.5 0.4]
#  The sample index is:  102 and the sample data is:  [7.1 3.  5.9 2.1]
#
# 5.
#  First Data Point of New Array:  [5.1 3.5 1.4 0.2 1. ]
#
# 6.
#  First Feature of New Array:  [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9 1. ]
